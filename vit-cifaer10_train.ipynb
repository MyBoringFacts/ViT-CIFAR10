# %% [markdown]
# REFERENCE:AN IMAGE IS WORTH 16X16 WORDS:TRANSFORMERS FOR IMAGE RECOGNITION AT SCALE
# https://openreview.net/pdf?id=YicbFdNTTy

# %% [markdown]
# Thadoe Hein 6511169

# %% [markdown]
# # Model Training
#
# - Initially, a traditional convolutional neural network (CNN) approach was attempted for CIFAR-10 classification. However, the CNN model struggled to achieve accuracy beyond 90%. To overcome this limitation, I implemented a Vision Transformer by searching through tutorials and following the original paper, which has shown promising results in various image classification tasks.
#
#
# - During training, an interesting phenomenon was observed where the test accuracy consistently exceeded the train accuracy.
#
# - I used stronger augmentation in my training data and it likely created more complex patterns, making it harder for the model to learn. As a result, the model performs better on the less complex, unaugmented test data. This indicates that my model is well-regularized and generalizes well to new data. This is also the very reason why the model test_accuracy is higher than the train_accuracy in the training phase.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from tqdm import tqdm
import numpy as np

# %% [markdown]
# ### Model Architecture
#
# The Vision Transformer (ViT) model used in this project is based on the original ViT paper "An Image is Worth 16x16 Words: Transformers for Image Recognition at Scale". Key components include:
#
# 1. Patch Embedding: Divides the input image into fixed-size patches and linearly embeds them.
# 2. Positional Embedding: Adds positional information to the patch embeddings.
# 3. Transformer Encoder: A stack of transformer blocks, each containing multi-head self-attention and feed-forward layers.
# 4. Classification Head: A linear layer for final classification.

# %%
class PatchEmbedding(nn.Module):
    def __init__(self, img_size, patch_size, in_chans, embed_dim):
        super().__init__()
        self.img_size = img_size
        self.patch_size = patch_size
        self.n_patches = (img_size // patch_size) ** 2
        self.proj = nn.Conv2d(in_chans, embed_dim, kernel_size=patch_size, stride=patch_size)

    def forward(self, x):
        x = self.proj(x)
        x = x.flatten(2).transpose(1, 2)
        return x

# %%
class Attention(nn.Module):
    def __init__(self, dim, num_heads=8, qkv_bias=False, attn_drop=0., proj_drop=0.):
        super().__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5

        self.qkv = nn.Linear(dim, dim * 3, bias=qkv_bias)
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)

    def forward(self, x):
        B, N, C = x.shape
        qkv = self.qkv(x).reshape(B, N, 3, self.num_heads, C // self.num_heads).permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]

        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        attn = self.attn_drop(attn)

        x = (attn @ v).transpose(1, 2).reshape(B, N, C)
        x = self.proj(x)
        x = self.proj_drop(x)
        return x

# %%
class Mlp(nn.Module):
    def __init__(self, in_features, hidden_features=None, out_features=None, act_layer=nn.GELU, drop=0.):
        super().__init__()
        out_features = out_features or in_features
        hidden_features = hidden_features or in_features
        self.fc1 = nn.Linear(in_features, hidden_features)
        self.act = act_layer()
        self.fc2 = nn.Linear(hidden_features, out_features)
        self.drop = nn.Dropout(drop)

    def forward(self, x):
        x = self.fc1(x)
        x = self.act(x)
        x = self.drop(x)
        x = self.fc2(x)
        x = self.drop(x)
        return x

# %%
class StochasticDepth(nn.Module):
    def __init__(self, drop_prob: float = 0.1):
        super().__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        if not self.training:
            return x

        keep_prob = 1 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (x.ndim - 1)
        random_tensor = keep_prob + torch.rand(shape, dtype=x.dtype, device=x.device)
        random_tensor.floor_()
        return x.div(keep_prob) * random_tensor

# %%
class Block(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio=4., qkv_bias=False, drop=0., attn_drop=0.,
                 drop_path=0., act_layer=nn.GELU, norm_layer=nn.LayerNorm):
        super().__init__()
        self.norm1 = norm_layer(dim)
        self.attn = Attention(dim, num_heads=num_heads, qkv_bias=qkv_bias, attn_drop=attn_drop, proj_drop=drop)
        self.drop_path = StochasticDepth(drop_path) if drop_path > 0. else nn.Identity()
        self.norm2 = norm_layer(dim)
        mlp_hidden_dim = int(dim * mlp_ratio)
        self.mlp = Mlp(in_features=dim, hidden_features=mlp_hidden_dim, act_layer=act_layer, drop=drop)

    def forward(self, x):
        x = x + self.drop_path(self.attn(self.norm1(x)))
        x = x + self.drop_path(self.mlp(self.norm2(x)))
        return x

# %%
class VisionTransformer(nn.Module):
    def __init__(self, img_size=32, patch_size=4, in_chans=3, num_classes=10, embed_dim=384, depth=12,
                 num_heads=6, mlp_ratio=4., qkv_bias=True, drop_rate=0.1, attn_drop_rate=0.1, drop_path_rate=0.1):
        super().__init__()
        self.patch_embed = PatchEmbedding(img_size, patch_size, in_chans, embed_dim)
        num_patches = self.patch_embed.n_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))
        self.pos_drop = nn.Dropout(p=drop_rate)

        dpr = [x.item() for x in torch.linspace(0, drop_path_rate, depth)]
        self.blocks = nn.ModuleList([
            Block(
                dim=embed_dim, num_heads=num_heads, mlp_ratio=mlp_ratio, qkv_bias=qkv_bias,
                drop=drop_rate, attn_drop=attn_drop_rate, drop_path=dpr[i])
            for i in range(depth)])

        self.norm = nn.LayerNorm(embed_dim)
        self.head = nn.Linear(embed_dim, num_classes)

    def forward(self, x):
        B = x.shape[0]
        x = self.patch_embed(x)

        cls_tokens = self.cls_token.expand(B, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embed
        x = self.pos_drop(x)

        for blk in self.blocks:
            x = blk(x)

        x = self.norm(x)
        x = x[:, 0]
        x = self.head(x)
        return x

# %%
# Mixup and CutMix functions
def mixup_data(x, y, alpha=1.0):
    lam = np.random.beta(alpha, alpha)
    batch_size = x.size()[0]
    index = torch.randperm(batch_size).to(x.device)
    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def cutmix_data(x, y, alpha=1.0):
    lam = np.random.beta(alpha, alpha)
    batch_size = x.size()[0]
    index = torch.randperm(batch_size).to(x.device)
    y_a, y_b = y, y[index]

    bbx1, bby1, bbx2, bby2 = rand_bbox(x.size(), lam)
    x[:, :, bbx1:bbx2, bby1:bby2] = x[index, :, bbx1:bbx2, bby1:bby2]
    lam = 1 - ((bbx2 - bbx1) * (bby2 - bby1) / (x.size()[-1] * x.size()[-2]))
    return x, y_a, y_b, lam
def rand_bbox(size, lam):
    W = size[2]
    H = size[3]
    cut_rat = np.sqrt(1. - lam)
    cut_w = int(W * cut_rat)
    cut_h = int(H * cut_rat)

    cx = np.random.randint(W)
    cy = np.random.randint(H)

    bbx1 = np.clip(cx - cut_w // 2, 0, W)
    bby1 = np.clip(cy - cut_h // 2, 0, H)
    bbx2 = np.clip(cx + cut_w // 2, 0, W)
    bby2 = np.clip(cy + cut_h // 2, 0, H)

    return bbx1, bby1, bbx2, bby2

# %% [markdown]
# ### Training Process
#
# The model is trained on the CIFAR-10 dataset, which consists of 60,000 32x32 color images in 10 classes. The training process includes:
#
# - Data augmentation techniques like random cropping and horizontal flipping.
# - Learning rate scheduling with warmup and cosine annealing.
# - Regularization techniques such as weight decay and dropout.
# - Training for 350 epochs to ensure convergence.

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Hyperparameters
batch_size = 128
num_epochs =350
learning_rate = 5e-4
weight_decay = 0.05
warmup_epochs = 5


# Data augmentation and normalization
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.RandAugment(num_ops=2, magnitude=9),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])





# Load CIFAR-10 dataset
train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)




# Initialize the model
model = VisionTransformer().to(device)

# Loss function and optimizer
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

# Learning rate scheduler with warmup and cosine annealing
def warmup_cosine_schedule(optimizer, warmup_epochs, max_epochs):
    def lr_lambda(epoch):
        if epoch < warmup_epochs:
            return epoch / warmup_epochs
        return 0.5 * (1 + np.cos(np.pi * (epoch - warmup_epochs) / (max_epochs - warmup_epochs)))
    
    return optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

scheduler = warmup_cosine_schedule(optimizer, warmup_epochs=warmup_epochs, max_epochs=num_epochs)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 47712673.10it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# ### Training
#
#
#
# #### The trained model will be saved as a checkpoint file every 50 epoch.

# %%
import os

checkpoint_path = 'checkpoints/'
os.makedirs(checkpoint_path, exist_ok=True)

train_accuracy_record = []
test_accuracy_record = []

print("5...4....3...2...1!!!")
print("Training START!!!!!!!!!!!")
for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        # Apply Mixup or CutMix
        if np.random.random() < 0.5:
            inputs, targets_a, targets_b, lam = mixup_data(inputs, targets)
        else:
            inputs, targets_a, targets_b, lam = cutmix_data(inputs, targets)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = lam * criterion(outputs, targets_a) + (1 - lam) * criterion(outputs, targets_b)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += (lam * predicted.eq(targets_a).sum().float() + (1 - lam) * predicted.eq(targets_b).sum().float())

    train_accuracy = 100. * correct / total
    train_accuracy_record.append(train_accuracy)
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss/len(train_loader):.4f}, Train Accuracy: {train_accuracy:.2f}%")

    # Validation
    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(test_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)        
            correct += predicted.eq(targets).sum().item()

    test_accuracy = 100. * correct / total
    test_accuracy_record .append(test_accuracy)
    print(f"Test Loss: {test_loss/len(test_loader):.4f}, Test Accuracy: {test_accuracy:.2f}%")

    scheduler.step()
    
    # Save checkpoint every 50 epochs
    if (epoch + 1) % 50 == 0:
        checkpoint_file = os.path.join(checkpoint_path, f'checkpoint_epoch_{epoch+1}.pt')
        torch.save({
            'epoch': epoch+1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'train_loss': train_loss,
            'test_loss': test_loss,
            'train_accuracy': train_accuracy,
            'test_accuracy': test_accuracy
        }, checkpoint_file)

print("Training finished!")
# Out:
# 5...4....3...2...1!!!
# Training START!!!!!!!!!!!
# Epoch [1/350], Train Loss: 2.4778, Train Accuracy: 8.57%
# Test Loss: 2.4965, Test Accuracy: 6.50%
# Epoch [2/350], Train Loss: 2.2257, Train Accuracy: 17.73%
# Test Loss: 2.0340, Test Accuracy: 26.04%
# Epoch [3/350], Train Loss: 2.1560, Train Accuracy: 21.75%
# Test Loss: 1.8743, Test Accuracy: 34.88%
# Epoch [4/350], Train Loss: 2.1061, Train Accuracy: 24.79%
# Test Loss: 1.8050, Test Accuracy: 41.02%
# Epoch [5/350], Train Loss: 2.0665, Train Accuracy: 27.41%
# Test Loss: 1.7178, Test Accuracy: 45.03%
# Epoch [6/350], Train Loss: 2.0510, Train Accuracy: 28.80%
# Test Loss: 1.7066, Test Accuracy: 47.46%
# Epoch [7/350], Train Loss: 2.0101, Train Accuracy: 31.10%
# Test Loss: 1.6871, Test Accuracy: 47.43%
# Epoch [8/350], Train Loss: 1.9900, Train Accuracy: 32.24%
# Test Loss: 1.5461, Test Accuracy: 52.86%
# Epoch [9/350], Train Loss: 1.9731, Train Accuracy: 33.28%
# Test Loss: 1.6117, Test Accuracy: 51.01%
# Epoch [10/350], Train Loss: 1.9599, Train Accuracy: 34.07%
# Test Loss: 1.5330, Test Accuracy: 53.41%
# Epoch [11/350], Train Loss: 1.9618, Train Accuracy: 34.05%
# Test Loss: 1.5520, Test Accuracy: 52.77%
# Epoch [12/350], Train Loss: 1.9415, Train Accuracy: 35.11%
# Test Loss: 1.4727, Test Accuracy: 57.20%
# Epoch [13/350], Train Loss: 1.9511, Train Accuracy: 34.64%
# Test Loss: 1.5425, Test Accuracy: 55.21%
# Epoch [14/350], Train Loss: 1.9271, Train Accuracy: 36.13%
# Test Loss: 1.5119, Test Accuracy: 54.62%
# Epoch [15/350], Train Loss: 1.9169, Train Accuracy: 36.29%
# Test Loss: 1.4579, Test Accuracy: 55.76%
# Epoch [16/350], Train Loss: 1.9135, Train Accuracy: 36.81%
# Test Loss: 1.3889, Test Accuracy: 60.35%
# Epoch [17/350], Train Loss: 1.8985, Train Accuracy: 37.65%
# Test Loss: 1.4412, Test Accuracy: 59.81%
# Epoch [18/350], Train Loss: 1.9153, Train Accuracy: 36.79%
# Test Loss: 1.4262, Test Accuracy: 59.96%
# Epoch [19/350], Train Loss: 1.8981, Train Accuracy: 37.71%
# Test Loss: 1.3774, Test Accuracy: 59.70%
# Epoch [20/350], Train Loss: 1.8872, Train Accuracy: 38.52%
# Test Loss: 1.4236, Test Accuracy: 58.59%
# Epoch [21/350], Train Loss: 1.8804, Train Accuracy: 38.73%
# Test Loss: 1.3888, Test Accuracy: 60.11%
# Epoch [22/350], Train Loss: 1.8690, Train Accuracy: 39.38%
# Test Loss: 1.3719, Test Accuracy: 62.27%
# Epoch [23/350], Train Loss: 1.8633, Train Accuracy: 39.62%
# Test Loss: 1.3675, Test Accuracy: 61.32%
# Epoch [24/350], Train Loss: 1.8503, Train Accuracy: 40.28%
# Test Loss: 1.3471, Test Accuracy: 63.17%
# Epoch [25/350], Train Loss: 1.8514, Train Accuracy: 40.51%
# Test Loss: 1.2886, Test Accuracy: 65.04%
# Epoch [26/350], Train Loss: 1.8494, Train Accuracy: 40.45%
# Test Loss: 1.2832, Test Accuracy: 65.71%
# Epoch [27/350], Train Loss: 1.8403, Train Accuracy: 41.19%
# Test Loss: 1.3191, Test Accuracy: 65.30%
# Epoch [28/350], Train Loss: 1.8156, Train Accuracy: 42.31%
# Test Loss: 1.2965, Test Accuracy: 65.63%
# Epoch [29/350], Train Loss: 1.8019, Train Accuracy: 42.96%
# Test Loss: 1.2613, Test Accuracy: 66.11%
# Epoch [30/350], Train Loss: 1.8043, Train Accuracy: 43.01%
# Test Loss: 1.2233, Test Accuracy: 68.96%
# Epoch [31/350], Train Loss: 1.8143, Train Accuracy: 42.42%
# Test Loss: 1.2386, Test Accuracy: 69.24%
# Epoch [32/350], Train Loss: 1.7906, Train Accuracy: 43.66%
# Test Loss: 1.2126, Test Accuracy: 68.91%
# Epoch [33/350], Train Loss: 1.8028, Train Accuracy: 43.19%
# Test Loss: 1.2207, Test Accuracy: 69.26%
# Epoch [34/350], Train Loss: 1.7845, Train Accuracy: 44.14%
# Test Loss: 1.2263, Test Accuracy: 68.95%
# Epoch [35/350], Train Loss: 1.7778, Train Accuracy: 44.50%
# Test Loss: 1.1841, Test Accuracy: 70.03%
# Epoch [36/350], Train Loss: 1.7594, Train Accuracy: 45.32%
# Test Loss: 1.2155, Test Accuracy: 69.64%
# Epoch [37/350], Train Loss: 1.7568, Train Accuracy: 45.39%
# Test Loss: 1.2024, Test Accuracy: 69.99%
# Epoch [38/350], Train Loss: 1.7476, Train Accuracy: 45.98%
# Test Loss: 1.1589, Test Accuracy: 71.44%
# Epoch [39/350], Train Loss: 1.7346, Train Accuracy: 46.72%
# Test Loss: 1.2121, Test Accuracy: 69.50%
# Epoch [40/350], Train Loss: 1.7715, Train Accuracy: 44.72%
# Test Loss: 1.1375, Test Accuracy: 72.86%
# Epoch [41/350], Train Loss: 1.7357, Train Accuracy: 46.77%
# Test Loss: 1.0896, Test Accuracy: 74.16%
# Epoch [42/350], Train Loss: 1.7212, Train Accuracy: 47.51%
# Test Loss: 1.1255, Test Accuracy: 72.35%
# Epoch [43/350], Train Loss: 1.7188, Train Accuracy: 47.56%
# Test Loss: 1.1345, Test Accuracy: 72.72%
# Epoch [44/350], Train Loss: 1.7217, Train Accuracy: 47.53%
# Test Loss: 1.1341, Test Accuracy: 73.56%
# Epoch [45/350], Train Loss: 1.7267, Train Accuracy: 47.19%
# Test Loss: 1.1014, Test Accuracy: 74.27%
# Epoch [46/350], Train Loss: 1.7043, Train Accuracy: 48.54%
# Test Loss: 1.0907, Test Accuracy: 74.70%
# Epoch [47/350], Train Loss: 1.7214, Train Accuracy: 47.35%
# Test Loss: 1.0713, Test Accuracy: 75.13%
# Epoch [48/350], Train Loss: 1.7076, Train Accuracy: 47.99%
# Test Loss: 1.0863, Test Accuracy: 74.61%
# Epoch [49/350], Train Loss: 1.7107, Train Accuracy: 48.11%
# Test Loss: 1.0761, Test Accuracy: 74.98%
# Epoch [50/350], Train Loss: 1.7018, Train Accuracy: 48.36%
# Test Loss: 1.0338, Test Accuracy: 76.68%
# Epoch [51/350], Train Loss: 1.6864, Train Accuracy: 49.14%
# Test Loss: 1.0737, Test Accuracy: 74.67%
# Epoch [52/350], Train Loss: 1.6893, Train Accuracy: 49.24%
# Test Loss: 1.0589, Test Accuracy: 75.96%
# Epoch [53/350], Train Loss: 1.6774, Train Accuracy: 49.55%
# Test Loss: 1.0478, Test Accuracy: 76.46%
# Epoch [54/350], Train Loss: 1.6596, Train Accuracy: 50.71%
# Test Loss: 1.0294, Test Accuracy: 77.05%
# Epoch [55/350], Train Loss: 1.6331, Train Accuracy: 51.88%
# Test Loss: 1.0005, Test Accuracy: 79.11%
# Epoch [56/350], Train Loss: 1.6359, Train Accuracy: 51.84%
# Test Loss: 1.0339, Test Accuracy: 77.38%
# Epoch [57/350], Train Loss: 1.6466, Train Accuracy: 51.53%
# Test Loss: 1.0131, Test Accuracy: 78.44%
# Epoch [58/350], Train Loss: 1.6565, Train Accuracy: 50.79%
# Test Loss: 1.0330, Test Accuracy: 77.79%
# Epoch [59/350], Train Loss: 1.6412, Train Accuracy: 51.66%
# Test Loss: 1.0485, Test Accuracy: 76.91%
# Epoch [60/350], Train Loss: 1.6464, Train Accuracy: 51.06%
# Test Loss: 1.0106, Test Accuracy: 78.44%
# Epoch [61/350], Train Loss: 1.6581, Train Accuracy: 50.60%
# Test Loss: 0.9663, Test Accuracy: 80.88%
# Epoch [62/350], Train Loss: 1.6131, Train Accuracy: 53.15%
# Test Loss: 0.9817, Test Accuracy: 80.05%
# Epoch [63/350], Train Loss: 1.6362, Train Accuracy: 51.72%
# Test Loss: 1.0172, Test Accuracy: 77.61%
# Epoch [64/350], Train Loss: 1.6199, Train Accuracy: 52.43%
# Test Loss: 0.9841, Test Accuracy: 79.70%
# Epoch [65/350], Train Loss: 1.6202, Train Accuracy: 52.55%
# Test Loss: 0.9563, Test Accuracy: 80.94%
# Epoch [66/350], Train Loss: 1.6353, Train Accuracy: 52.06%
# Test Loss: 0.9920, Test Accuracy: 80.55%
# Epoch [67/350], Train Loss: 1.6209, Train Accuracy: 52.37%
# Test Loss: 0.9680, Test Accuracy: 79.82%
# Epoch [68/350], Train Loss: 1.6090, Train Accuracy: 53.06%
# Test Loss: 0.9440, Test Accuracy: 81.33%
# Epoch [69/350], Train Loss: 1.5943, Train Accuracy: 53.90%
# Test Loss: 0.9561, Test Accuracy: 81.25%
# Epoch [70/350], Train Loss: 1.6287, Train Accuracy: 52.46%
# Test Loss: 0.9815, Test Accuracy: 79.75%
# Epoch [71/350], Train Loss: 1.6062, Train Accuracy: 53.34%
# Test Loss: 0.9769, Test Accuracy: 79.76%
# Epoch [72/350], Train Loss: 1.5834, Train Accuracy: 54.51%
# Test Loss: 0.9438, Test Accuracy: 82.64%
# Epoch [73/350], Train Loss: 1.5791, Train Accuracy: 54.62%
# Test Loss: 0.9292, Test Accuracy: 81.95%
# Epoch [74/350], Train Loss: 1.6016, Train Accuracy: 53.43%
# Test Loss: 0.9207, Test Accuracy: 82.49%
# Epoch [75/350], Train Loss: 1.5662, Train Accuracy: 55.27%
# Test Loss: 0.9229, Test Accuracy: 82.60%
# Epoch [76/350], Train Loss: 1.5824, Train Accuracy: 54.33%
# Test Loss: 0.9240, Test Accuracy: 82.60%
# Epoch [77/350], Train Loss: 1.5724, Train Accuracy: 54.83%
# Test Loss: 0.9287, Test Accuracy: 83.05%
# Epoch [78/350], Train Loss: 1.5807, Train Accuracy: 54.52%
# Test Loss: 0.9155, Test Accuracy: 83.10%
# Epoch [79/350], Train Loss: 1.5634, Train Accuracy: 55.50%
# Test Loss: 0.9135, Test Accuracy: 83.44%
# Epoch [80/350], Train Loss: 1.5580, Train Accuracy: 55.63%
# Test Loss: 0.9068, Test Accuracy: 82.38%
# Epoch [81/350], Train Loss: 1.5962, Train Accuracy: 53.69%
# Test Loss: 0.9138, Test Accuracy: 82.80%
# Epoch [82/350], Train Loss: 1.5673, Train Accuracy: 55.28%
# Test Loss: 0.8982, Test Accuracy: 83.68%
# Epoch [83/350], Train Loss: 1.5545, Train Accuracy: 55.92%
# Test Loss: 0.9026, Test Accuracy: 84.25%
# Epoch [84/350], Train Loss: 1.5457, Train Accuracy: 56.07%
# Test Loss: 0.8836, Test Accuracy: 83.66%
# Epoch [85/350], Train Loss: 1.5563, Train Accuracy: 55.87%
# Test Loss: 0.9018, Test Accuracy: 83.75%
# Epoch [86/350], Train Loss: 1.5458, Train Accuracy: 56.38%
# Test Loss: 0.8983, Test Accuracy: 84.17%
# Epoch [87/350], Train Loss: 1.5497, Train Accuracy: 56.16%
# Test Loss: 0.9158, Test Accuracy: 83.41%
# Epoch [88/350], Train Loss: 1.5501, Train Accuracy: 56.06%
# Test Loss: 0.8931, Test Accuracy: 84.19%
# Epoch [89/350], Train Loss: 1.5589, Train Accuracy: 55.83%
# Test Loss: 0.8930, Test Accuracy: 84.14%
# Epoch [90/350], Train Loss: 1.5545, Train Accuracy: 55.89%
# Test Loss: 0.8938, Test Accuracy: 84.29%
# Epoch [91/350], Train Loss: 1.5575, Train Accuracy: 55.73%
# Test Loss: 0.8674, Test Accuracy: 84.84%
# Epoch [92/350], Train Loss: 1.5398, Train Accuracy: 56.81%
# Test Loss: 0.8801, Test Accuracy: 84.32%
# Epoch [93/350], Train Loss: 1.5344, Train Accuracy: 56.70%
# Test Loss: 0.8699, Test Accuracy: 85.07%
# Epoch [94/350], Train Loss: 1.5298, Train Accuracy: 56.97%
# Test Loss: 0.8676, Test Accuracy: 84.52%
# Epoch [95/350], Train Loss: 1.5410, Train Accuracy: 56.70%
# Test Loss: 0.8860, Test Accuracy: 84.12%
# Epoch [96/350], Train Loss: 1.5478, Train Accuracy: 56.13%
# Test Loss: 0.8923, Test Accuracy: 84.37%
# Epoch [97/350], Train Loss: 1.5468, Train Accuracy: 56.21%
# Test Loss: 0.8712, Test Accuracy: 85.24%
# Epoch [98/350], Train Loss: 1.5346, Train Accuracy: 56.91%
# Test Loss: 0.8557, Test Accuracy: 85.43%
# Epoch [99/350], Train Loss: 1.5210, Train Accuracy: 57.66%
# Test Loss: 0.8618, Test Accuracy: 84.69%
# Epoch [100/350], Train Loss: 1.5207, Train Accuracy: 57.36%
# Test Loss: 0.8714, Test Accuracy: 84.77%
# Epoch [101/350], Train Loss: 1.5141, Train Accuracy: 57.66%
# Test Loss: 0.8671, Test Accuracy: 85.15%
# Epoch [102/350], Train Loss: 1.5342, Train Accuracy: 56.91%
# Test Loss: 0.8706, Test Accuracy: 85.01%
# Epoch [103/350], Train Loss: 1.5044, Train Accuracy: 58.68%
# Test Loss: 0.8658, Test Accuracy: 85.85%
# Epoch [104/350], Train Loss: 1.5368, Train Accuracy: 56.91%
# Test Loss: 0.8697, Test Accuracy: 85.15%
# Epoch [105/350], Train Loss: 1.5136, Train Accuracy: 57.86%
# Test Loss: 0.8438, Test Accuracy: 86.35%
# Epoch [106/350], Train Loss: 1.4748, Train Accuracy: 59.66%
# Test Loss: 0.8492, Test Accuracy: 85.37%
# Epoch [107/350], Train Loss: 1.5013, Train Accuracy: 58.50%
# Test Loss: 0.8603, Test Accuracy: 86.08%
# Epoch [108/350], Train Loss: 1.5138, Train Accuracy: 57.41%
# Test Loss: 0.8532, Test Accuracy: 85.54%
# Epoch [109/350], Train Loss: 1.5256, Train Accuracy: 57.23%
# Test Loss: 0.8527, Test Accuracy: 86.49%
# Epoch [110/350], Train Loss: 1.5073, Train Accuracy: 58.23%
# Test Loss: 0.8499, Test Accuracy: 86.43%
# Epoch [111/350], Train Loss: 1.4987, Train Accuracy: 58.55%
# Test Loss: 0.8421, Test Accuracy: 86.20%
# Epoch [112/350], Train Loss: 1.4867, Train Accuracy: 59.27%
# Test Loss: 0.8442, Test Accuracy: 85.68%
# Epoch [113/350], Train Loss: 1.5315, Train Accuracy: 56.85%
# Test Loss: 0.8391, Test Accuracy: 85.84%
# Epoch [114/350], Train Loss: 1.4634, Train Accuracy: 60.30%
# Test Loss: 0.8465, Test Accuracy: 86.21%
# Epoch [115/350], Train Loss: 1.5026, Train Accuracy: 58.02%
# Test Loss: 0.8172, Test Accuracy: 87.28%
# Epoch [116/350], Train Loss: 1.4982, Train Accuracy: 58.59%
# Test Loss: 0.8113, Test Accuracy: 87.66%
# Epoch [117/350], Train Loss: 1.4729, Train Accuracy: 59.66%
# Test Loss: 0.8241, Test Accuracy: 87.14%
# Epoch [118/350], Train Loss: 1.4770, Train Accuracy: 59.51%
# Test Loss: 0.8347, Test Accuracy: 86.61%
# Epoch [119/350], Train Loss: 1.4798, Train Accuracy: 59.43%
# Test Loss: 0.8463, Test Accuracy: 85.88%
# Epoch [120/350], Train Loss: 1.4838, Train Accuracy: 59.19%
# Test Loss: 0.8217, Test Accuracy: 87.32%
# Epoch [121/350], Train Loss: 1.4662, Train Accuracy: 60.17%
# Test Loss: 0.8118, Test Accuracy: 87.40%
# Epoch [122/350], Train Loss: 1.4490, Train Accuracy: 60.83%
# Test Loss: 0.8123, Test Accuracy: 87.23%
# Epoch [123/350], Train Loss: 1.4616, Train Accuracy: 60.11%
# Test Loss: 0.8125, Test Accuracy: 87.15%
# Epoch [124/350], Train Loss: 1.4618, Train Accuracy: 60.10%
# Test Loss: 0.8084, Test Accuracy: 87.40%
# Epoch [125/350], Train Loss: 1.4619, Train Accuracy: 60.20%
# Test Loss: 0.8178, Test Accuracy: 87.31%
# Epoch [126/350], Train Loss: 1.4645, Train Accuracy: 60.10%
# Test Loss: 0.8205, Test Accuracy: 86.81%
# Epoch [127/350], Train Loss: 1.4729, Train Accuracy: 59.55%
# Test Loss: 0.8345, Test Accuracy: 86.95%
# Epoch [128/350], Train Loss: 1.4573, Train Accuracy: 60.34%
# Test Loss: 0.8210, Test Accuracy: 87.48%
# Epoch [129/350], Train Loss: 1.4624, Train Accuracy: 60.10%
# Test Loss: 0.8126, Test Accuracy: 87.46%
# Epoch [130/350], Train Loss: 1.4573, Train Accuracy: 60.38%
# Test Loss: 0.8298, Test Accuracy: 87.06%
# Epoch [131/350], Train Loss: 1.4808, Train Accuracy: 59.21%
# Test Loss: 0.8094, Test Accuracy: 88.13%
# Epoch [132/350], Train Loss: 1.4444, Train Accuracy: 61.03%
# Test Loss: 0.8022, Test Accuracy: 88.03%
# Epoch [133/350], Train Loss: 1.4655, Train Accuracy: 60.07%
# Test Loss: 0.8138, Test Accuracy: 87.65%
# Epoch [134/350], Train Loss: 1.4427, Train Accuracy: 60.91%
# Test Loss: 0.8086, Test Accuracy: 87.72%
# Epoch [135/350], Train Loss: 1.4536, Train Accuracy: 60.73%
# Test Loss: 0.8099, Test Accuracy: 87.90%
# Epoch [136/350], Train Loss: 1.4495, Train Accuracy: 60.73%
# Test Loss: 0.8049, Test Accuracy: 88.11%
# Epoch [137/350], Train Loss: 1.4433, Train Accuracy: 61.26%
# Test Loss: 0.8066, Test Accuracy: 88.25%
# Epoch [138/350], Train Loss: 1.4804, Train Accuracy: 59.11%
# Test Loss: 0.8032, Test Accuracy: 88.16%
# Epoch [139/350], Train Loss: 1.4482, Train Accuracy: 60.49%
# Test Loss: 0.7990, Test Accuracy: 88.36%
# Epoch [140/350], Train Loss: 1.4531, Train Accuracy: 60.42%
# Test Loss: 0.7973, Test Accuracy: 87.95%
# Epoch [141/350], Train Loss: 1.4588, Train Accuracy: 60.28%
# Test Loss: 0.7977, Test Accuracy: 88.05%
# Epoch [142/350], Train Loss: 1.4471, Train Accuracy: 61.04%
# Test Loss: 0.7794, Test Accuracy: 88.90%
# Epoch [143/350], Train Loss: 1.4536, Train Accuracy: 60.58%
# Test Loss: 0.8025, Test Accuracy: 87.79%
# Epoch [144/350], Train Loss: 1.4488, Train Accuracy: 60.82%
# Test Loss: 0.7811, Test Accuracy: 88.19%
# Epoch [145/350], Train Loss: 1.4425, Train Accuracy: 60.90%
# Test Loss: 0.8139, Test Accuracy: 87.92%
# Epoch [146/350], Train Loss: 1.4421, Train Accuracy: 61.35%
# Test Loss: 0.7830, Test Accuracy: 88.85%
# Epoch [147/350], Train Loss: 1.4513, Train Accuracy: 60.60%
# Test Loss: 0.7980, Test Accuracy: 88.64%
# Epoch [148/350], Train Loss: 1.4355, Train Accuracy: 61.35%
# Test Loss: 0.7898, Test Accuracy: 88.73%
# Epoch [149/350], Train Loss: 1.4280, Train Accuracy: 61.74%
# Test Loss: 0.8045, Test Accuracy: 87.94%
# Epoch [150/350], Train Loss: 1.4269, Train Accuracy: 61.56%
# Test Loss: 0.7824, Test Accuracy: 88.98%
# Epoch [151/350], Train Loss: 1.4599, Train Accuracy: 60.19%
# Test Loss: 0.7841, Test Accuracy: 88.97%
# Epoch [152/350], Train Loss: 1.4045, Train Accuracy: 62.85%
# Test Loss: 0.7870, Test Accuracy: 88.56%
# Epoch [153/350], Train Loss: 1.4328, Train Accuracy: 61.55%
# Test Loss: 0.7839, Test Accuracy: 89.08%
# Epoch [154/350], Train Loss: 1.4341, Train Accuracy: 61.26%
# Test Loss: 0.7756, Test Accuracy: 88.52%
# Epoch [155/350], Train Loss: 1.4341, Train Accuracy: 61.40%
# Test Loss: 0.7711, Test Accuracy: 88.96%
# Epoch [156/350], Train Loss: 1.4692, Train Accuracy: 59.73%
# Test Loss: 0.7913, Test Accuracy: 88.69%
# Epoch [157/350], Train Loss: 1.4130, Train Accuracy: 62.04%
# Test Loss: 0.7757, Test Accuracy: 88.81%
# Epoch [158/350], Train Loss: 1.4383, Train Accuracy: 60.76%
# Test Loss: 0.7728, Test Accuracy: 88.85%
# Epoch [159/350], Train Loss: 1.3957, Train Accuracy: 63.16%
# Test Loss: 0.7690, Test Accuracy: 89.24%
# Epoch [160/350], Train Loss: 1.4236, Train Accuracy: 61.75%
# Test Loss: 0.7784, Test Accuracy: 88.86%
# Epoch [161/350], Train Loss: 1.4041, Train Accuracy: 62.75%
# Test Loss: 0.7638, Test Accuracy: 89.30%
# Epoch [162/350], Train Loss: 1.3986, Train Accuracy: 63.30%
# Test Loss: 0.7757, Test Accuracy: 89.25%
# Epoch [163/350], Train Loss: 1.4269, Train Accuracy: 61.63%
# Test Loss: 0.7793, Test Accuracy: 88.78%
# Epoch [164/350], Train Loss: 1.4085, Train Accuracy: 62.47%
# Test Loss: 0.7716, Test Accuracy: 88.98%
# Epoch [165/350], Train Loss: 1.4228, Train Accuracy: 61.66%
# Test Loss: 0.7846, Test Accuracy: 88.50%
# Epoch [166/350], Train Loss: 1.4096, Train Accuracy: 62.82%
# Test Loss: 0.7731, Test Accuracy: 88.96%
# Epoch [167/350], Train Loss: 1.3928, Train Accuracy: 63.54%
# Test Loss: 0.7671, Test Accuracy: 89.13%
# Epoch [168/350], Train Loss: 1.4062, Train Accuracy: 62.85%
# Test Loss: 0.7797, Test Accuracy: 89.20%
# Epoch [169/350], Train Loss: 1.3755, Train Accuracy: 64.16%
# Test Loss: 0.7626, Test Accuracy: 89.77%
# Epoch [170/350], Train Loss: 1.4225, Train Accuracy: 61.98%
# Test Loss: 0.7654, Test Accuracy: 89.45%
# Epoch [171/350], Train Loss: 1.3866, Train Accuracy: 63.42%
# Test Loss: 0.7653, Test Accuracy: 89.13%
# Epoch [172/350], Train Loss: 1.3932, Train Accuracy: 63.39%
# Test Loss: 0.7672, Test Accuracy: 89.47%
# Epoch [173/350], Train Loss: 1.3781, Train Accuracy: 64.03%
# Test Loss: 0.7641, Test Accuracy: 89.90%
# Epoch [174/350], Train Loss: 1.3993, Train Accuracy: 62.55%
# Test Loss: 0.7617, Test Accuracy: 89.27%
# Epoch [175/350], Train Loss: 1.3877, Train Accuracy: 63.39%
# Test Loss: 0.7641, Test Accuracy: 90.02%
# Epoch [176/350], Train Loss: 1.3894, Train Accuracy: 63.30%
# Test Loss: 0.7703, Test Accuracy: 89.74%
# Epoch [177/350], Train Loss: 1.4060, Train Accuracy: 62.35%
# Test Loss: 0.7722, Test Accuracy: 89.53%
# Epoch [178/350], Train Loss: 1.3751, Train Accuracy: 64.19%
# Test Loss: 0.7506, Test Accuracy: 90.16%
# Epoch [179/350], Train Loss: 1.3969, Train Accuracy: 63.08%
# Test Loss: 0.7540, Test Accuracy: 89.72%
# Epoch [180/350], Train Loss: 1.3745, Train Accuracy: 64.15%
# Test Loss: 0.7510, Test Accuracy: 89.86%
# Epoch [181/350], Train Loss: 1.4047, Train Accuracy: 62.50%
# Test Loss: 0.7441, Test Accuracy: 90.52%
# Epoch [182/350], Train Loss: 1.3915, Train Accuracy: 63.46%
# Test Loss: 0.7790, Test Accuracy: 89.63%
# Epoch [183/350], Train Loss: 1.4104, Train Accuracy: 62.34%
# Test Loss: 0.7635, Test Accuracy: 90.10%
# Epoch [184/350], Train Loss: 1.3823, Train Accuracy: 63.79%
# Test Loss: 0.7522, Test Accuracy: 90.30%
# Epoch [185/350], Train Loss: 1.3716, Train Accuracy: 64.34%
# Test Loss: 0.7528, Test Accuracy: 90.17%
# Epoch [186/350], Train Loss: 1.3905, Train Accuracy: 63.52%
# Test Loss: 0.7714, Test Accuracy: 89.99%
# Epoch [187/350], Train Loss: 1.3647, Train Accuracy: 64.69%
# Test Loss: 0.7499, Test Accuracy: 90.17%
# Epoch [188/350], Train Loss: 1.3965, Train Accuracy: 62.81%
# Test Loss: 0.7531, Test Accuracy: 90.06%
# Epoch [189/350], Train Loss: 1.3903, Train Accuracy: 63.33%
# Test Loss: 0.7515, Test Accuracy: 90.07%
# Epoch [190/350], Train Loss: 1.3876, Train Accuracy: 63.19%
# Test Loss: 0.7553, Test Accuracy: 90.05%
# Epoch [191/350], Train Loss: 1.3673, Train Accuracy: 64.49%
# Test Loss: 0.7378, Test Accuracy: 90.71%
# Epoch [192/350], Train Loss: 1.3651, Train Accuracy: 64.38%
# Test Loss: 0.7609, Test Accuracy: 90.22%
# Epoch [193/350], Train Loss: 1.3997, Train Accuracy: 62.43%
# Test Loss: 0.7552, Test Accuracy: 90.23%
# Epoch [194/350], Train Loss: 1.3600, Train Accuracy: 64.78%
# Test Loss: 0.7589, Test Accuracy: 90.02%
# Epoch [195/350], Train Loss: 1.4056, Train Accuracy: 62.45%
# Test Loss: 0.7568, Test Accuracy: 90.14%
# Epoch [196/350], Train Loss: 1.3645, Train Accuracy: 64.55%
# Test Loss: 0.7570, Test Accuracy: 90.22%
# Epoch [197/350], Train Loss: 1.3786, Train Accuracy: 63.75%
# Test Loss: 0.7383, Test Accuracy: 90.69%
# Epoch [198/350], Train Loss: 1.3977, Train Accuracy: 63.05%
# Test Loss: 0.7471, Test Accuracy: 90.73%
# Epoch [199/350], Train Loss: 1.3577, Train Accuracy: 64.65%
# Test Loss: 0.7433, Test Accuracy: 90.84%
# Epoch [200/350], Train Loss: 1.3596, Train Accuracy: 64.92%
# Test Loss: 0.7492, Test Accuracy: 90.71%
# Epoch [201/350], Train Loss: 1.3519, Train Accuracy: 64.72%
# Test Loss: 0.7545, Test Accuracy: 90.48%
# Epoch [202/350], Train Loss: 1.3939, Train Accuracy: 62.74%
# Test Loss: 0.7485, Test Accuracy: 90.72%
# Epoch [203/350], Train Loss: 1.3819, Train Accuracy: 63.53%
# Test Loss: 0.7502, Test Accuracy: 90.38%
# Epoch [204/350], Train Loss: 1.3507, Train Accuracy: 64.76%
# Test Loss: 0.7288, Test Accuracy: 91.43%
# Epoch [205/350], Train Loss: 1.3623, Train Accuracy: 64.74%
# Test Loss: 0.7463, Test Accuracy: 90.34%
# Epoch [206/350], Train Loss: 1.3640, Train Accuracy: 64.38%
# Test Loss: 0.7419, Test Accuracy: 90.87%
# Epoch [207/350], Train Loss: 1.3443, Train Accuracy: 65.20%
# Test Loss: 0.7474, Test Accuracy: 90.65%
# Epoch [208/350], Train Loss: 1.3631, Train Accuracy: 64.38%
# Test Loss: 0.7492, Test Accuracy: 90.47%
# Epoch [209/350], Train Loss: 1.3776, Train Accuracy: 63.57%
# Test Loss: 0.7419, Test Accuracy: 90.80%
# Epoch [210/350], Train Loss: 1.3472, Train Accuracy: 65.33%
# Test Loss: 0.7347, Test Accuracy: 91.06%
# Epoch [211/350], Train Loss: 1.3440, Train Accuracy: 65.24%
# Test Loss: 0.7435, Test Accuracy: 90.71%
# Epoch [212/350], Train Loss: 1.3368, Train Accuracy: 65.68%
# Test Loss: 0.7267, Test Accuracy: 91.46%
# Epoch [213/350], Train Loss: 1.3564, Train Accuracy: 64.66%
# Test Loss: 0.7342, Test Accuracy: 91.09%
# Epoch [214/350], Train Loss: 1.3557, Train Accuracy: 64.66%
# Test Loss: 0.7420, Test Accuracy: 90.88%
# Epoch [215/350], Train Loss: 1.3488, Train Accuracy: 65.05%
# Test Loss: 0.7397, Test Accuracy: 90.76%
# Epoch [216/350], Train Loss: 1.3537, Train Accuracy: 64.92%
# Test Loss: 0.7372, Test Accuracy: 91.11%
# Epoch [217/350], Train Loss: 1.3476, Train Accuracy: 65.07%
# Test Loss: 0.7335, Test Accuracy: 91.49%
# Epoch [218/350], Train Loss: 1.3181, Train Accuracy: 66.93%
# Test Loss: 0.7326, Test Accuracy: 91.38%
# Epoch [219/350], Train Loss: 1.3446, Train Accuracy: 65.01%
# Test Loss: 0.7411, Test Accuracy: 91.12%
# Epoch [220/350], Train Loss: 1.3551, Train Accuracy: 64.41%
# Test Loss: 0.7372, Test Accuracy: 91.26%
# Epoch [221/350], Train Loss: 1.3630, Train Accuracy: 64.06%
# Test Loss: 0.7324, Test Accuracy: 91.16%
# Epoch [222/350], Train Loss: 1.3403, Train Accuracy: 65.64%
# Test Loss: 0.7400, Test Accuracy: 90.94%
# Epoch [223/350], Train Loss: 1.3186, Train Accuracy: 66.59%
# Test Loss: 0.7284, Test Accuracy: 91.20%
# Epoch [224/350], Train Loss: 1.3462, Train Accuracy: 65.06%
# Test Loss: 0.7382, Test Accuracy: 91.01%
# Epoch [225/350], Train Loss: 1.3508, Train Accuracy: 64.85%
# Test Loss: 0.7289, Test Accuracy: 91.51%
# Epoch [226/350], Train Loss: 1.3271, Train Accuracy: 66.03%
# Test Loss: 0.7273, Test Accuracy: 91.14%
# Epoch [227/350], Train Loss: 1.3491, Train Accuracy: 65.08%
# Test Loss: 0.7307, Test Accuracy: 91.45%
# Epoch [228/350], Train Loss: 1.3386, Train Accuracy: 65.52%
# Test Loss: 0.7341, Test Accuracy: 91.44%
# Epoch [229/350], Train Loss: 1.3458, Train Accuracy: 65.15%
# Test Loss: 0.7259, Test Accuracy: 91.40%
# Epoch [230/350], Train Loss: 1.3213, Train Accuracy: 66.20%
# Test Loss: 0.7253, Test Accuracy: 91.25%
# Epoch [231/350], Train Loss: 1.3326, Train Accuracy: 65.69%
# Test Loss: 0.7291, Test Accuracy: 91.29%
# Epoch [232/350], Train Loss: 1.3185, Train Accuracy: 66.24%
# Test Loss: 0.7356, Test Accuracy: 90.87%
# Epoch [233/350], Train Loss: 1.3289, Train Accuracy: 66.16%
# Test Loss: 0.7293, Test Accuracy: 91.44%
# Epoch [234/350], Train Loss: 1.3392, Train Accuracy: 65.41%
# Test Loss: 0.7230, Test Accuracy: 91.46%
# Epoch [235/350], Train Loss: 1.3085, Train Accuracy: 66.39%
# Test Loss: 0.7215, Test Accuracy: 91.72%
# Epoch [236/350], Train Loss: 1.3409, Train Accuracy: 65.12%
# Test Loss: 0.7216, Test Accuracy: 91.36%
# Epoch [237/350], Train Loss: 1.2932, Train Accuracy: 67.67%
# Test Loss: 0.7261, Test Accuracy: 91.57%
# Epoch [238/350], Train Loss: 1.3381, Train Accuracy: 65.32%
# Test Loss: 0.7192, Test Accuracy: 91.42%
# Epoch [239/350], Train Loss: 1.3101, Train Accuracy: 66.89%
# Test Loss: 0.7211, Test Accuracy: 91.71%
# Epoch [240/350], Train Loss: 1.3445, Train Accuracy: 65.21%
# Test Loss: 0.7234, Test Accuracy: 91.49%
# Epoch [241/350], Train Loss: 1.3163, Train Accuracy: 66.30%
# Test Loss: 0.7217, Test Accuracy: 91.34%
# Epoch [242/350], Train Loss: 1.3217, Train Accuracy: 66.15%
# Test Loss: 0.7341, Test Accuracy: 91.11%
# Epoch [243/350], Train Loss: 1.2863, Train Accuracy: 68.07%
# Test Loss: 0.7198, Test Accuracy: 91.69%
# Epoch [244/350], Train Loss: 1.3139, Train Accuracy: 66.48%
# Test Loss: 0.7196, Test Accuracy: 91.63%
# Epoch [245/350], Train Loss: 1.3231, Train Accuracy: 66.11%
# Test Loss: 0.7266, Test Accuracy: 91.41%
# Epoch [246/350], Train Loss: 1.3120, Train Accuracy: 66.59%
# Test Loss: 0.7229, Test Accuracy: 91.92%
# Epoch [247/350], Train Loss: 1.3261, Train Accuracy: 65.92%
# Test Loss: 0.7259, Test Accuracy: 91.29%
# Epoch [248/350], Train Loss: 1.3088, Train Accuracy: 66.71%
# Test Loss: 0.7320, Test Accuracy: 91.25%
# Epoch [249/350], Train Loss: 1.2908, Train Accuracy: 67.69%
# Test Loss: 0.7162, Test Accuracy: 91.78%
# Epoch [250/350], Train Loss: 1.3203, Train Accuracy: 66.06%
# Test Loss: 0.7137, Test Accuracy: 91.75%
# Epoch [251/350], Train Loss: 1.2904, Train Accuracy: 67.37%
# Test Loss: 0.7154, Test Accuracy: 91.77%
# Epoch [252/350], Train Loss: 1.2978, Train Accuracy: 67.41%
# Test Loss: 0.7201, Test Accuracy: 91.84%
# Epoch [253/350], Train Loss: 1.2955, Train Accuracy: 67.29%
# Test Loss: 0.7204, Test Accuracy: 91.57%
# Epoch [254/350], Train Loss: 1.3087, Train Accuracy: 66.88%
# Test Loss: 0.7154, Test Accuracy: 91.93%
# Epoch [255/350], Train Loss: 1.2938, Train Accuracy: 67.40%
# Test Loss: 0.7147, Test Accuracy: 91.81%
# Epoch [256/350], Train Loss: 1.3299, Train Accuracy: 65.27%
# Test Loss: 0.7199, Test Accuracy: 92.08%
# Epoch [257/350], Train Loss: 1.2796, Train Accuracy: 68.29%
# Test Loss: 0.7128, Test Accuracy: 92.02%
# Epoch [258/350], Train Loss: 1.3079, Train Accuracy: 66.78%
# Test Loss: 0.7212, Test Accuracy: 91.77%
# Epoch [259/350], Train Loss: 1.3370, Train Accuracy: 65.16%
# Test Loss: 0.7222, Test Accuracy: 91.68%
# Epoch [260/350], Train Loss: 1.2962, Train Accuracy: 67.06%
# Test Loss: 0.7187, Test Accuracy: 91.79%
# Epoch [261/350], Train Loss: 1.3115, Train Accuracy: 66.23%
# Test Loss: 0.7343, Test Accuracy: 91.29%
# Epoch [262/350], Train Loss: 1.2969, Train Accuracy: 67.13%
# Test Loss: 0.7347, Test Accuracy: 91.25%
# Epoch [263/350], Train Loss: 1.2932, Train Accuracy: 67.19%
# Test Loss: 0.7228, Test Accuracy: 91.54%
# Epoch [264/350], Train Loss: 1.3035, Train Accuracy: 66.87%
# Test Loss: 0.7175, Test Accuracy: 91.85%
# Epoch [265/350], Train Loss: 1.3007, Train Accuracy: 66.71%
# Test Loss: 0.7167, Test Accuracy: 92.04%
# Epoch [266/350], Train Loss: 1.3156, Train Accuracy: 66.04%
# Test Loss: 0.7227, Test Accuracy: 91.97%
# Epoch [267/350], Train Loss: 1.3165, Train Accuracy: 66.00%
# Test Loss: 0.7155, Test Accuracy: 92.02%
# Epoch [268/350], Train Loss: 1.2809, Train Accuracy: 68.15%
# Test Loss: 0.7176, Test Accuracy: 91.98%
# Epoch [269/350], Train Loss: 1.2671, Train Accuracy: 68.51%
# Test Loss: 0.7159, Test Accuracy: 91.96%
# Epoch [270/350], Train Loss: 1.2759, Train Accuracy: 68.28%
# Test Loss: 0.7139, Test Accuracy: 92.15%
# Epoch [271/350], Train Loss: 1.3109, Train Accuracy: 66.33%
# Test Loss: 0.7197, Test Accuracy: 91.95%
# Epoch [272/350], Train Loss: 1.2955, Train Accuracy: 67.18%
# Test Loss: 0.7174, Test Accuracy: 91.90%
# Epoch [273/350], Train Loss: 1.2767, Train Accuracy: 68.25%
# Test Loss: 0.7167, Test Accuracy: 92.28%
# Epoch [274/350], Train Loss: 1.2852, Train Accuracy: 67.49%
# Test Loss: 0.7155, Test Accuracy: 92.35%
# Epoch [275/350], Train Loss: 1.3106, Train Accuracy: 66.06%
# Test Loss: 0.7140, Test Accuracy: 92.16%
# Epoch [276/350], Train Loss: 1.2775, Train Accuracy: 68.19%
# Test Loss: 0.7117, Test Accuracy: 92.14%
# Epoch [277/350], Train Loss: 1.2688, Train Accuracy: 68.32%
# Test Loss: 0.7110, Test Accuracy: 92.01%
# Epoch [278/350], Train Loss: 1.2696, Train Accuracy: 68.62%
# Test Loss: 0.7077, Test Accuracy: 92.45%
# Epoch [279/350], Train Loss: 1.3038, Train Accuracy: 66.63%
# Test Loss: 0.7102, Test Accuracy: 92.07%
# Epoch [280/350], Train Loss: 1.2814, Train Accuracy: 67.61%
# Test Loss: 0.7197, Test Accuracy: 91.80%
# Epoch [281/350], Train Loss: 1.2845, Train Accuracy: 67.83%
# Test Loss: 0.7113, Test Accuracy: 92.21%
# Epoch [282/350], Train Loss: 1.2811, Train Accuracy: 67.57%
# Test Loss: 0.7139, Test Accuracy: 92.19%
# Epoch [283/350], Train Loss: 1.2730, Train Accuracy: 68.10%
# Test Loss: 0.7108, Test Accuracy: 92.32%
# Epoch [284/350], Train Loss: 1.2797, Train Accuracy: 67.72%
# Test Loss: 0.7139, Test Accuracy: 92.16%
# Epoch [285/350], Train Loss: 1.2536, Train Accuracy: 69.04%
# Test Loss: 0.7116, Test Accuracy: 92.02%
# Epoch [286/350], Train Loss: 1.2588, Train Accuracy: 69.20%
# Test Loss: 0.7119, Test Accuracy: 92.09%
# Epoch [287/350], Train Loss: 1.2845, Train Accuracy: 67.62%
# Test Loss: 0.7108, Test Accuracy: 92.14%
# Epoch [288/350], Train Loss: 1.2936, Train Accuracy: 67.02%
# Test Loss: 0.7125, Test Accuracy: 92.20%
# Epoch [289/350], Train Loss: 1.2769, Train Accuracy: 67.83%
# Test Loss: 0.7133, Test Accuracy: 92.11%
# Epoch [290/350], Train Loss: 1.2872, Train Accuracy: 67.20%
# Test Loss: 0.7104, Test Accuracy: 92.17%
# Epoch [291/350], Train Loss: 1.2820, Train Accuracy: 67.50%
# Test Loss: 0.7137, Test Accuracy: 92.27%
# Epoch [292/350], Train Loss: 1.2733, Train Accuracy: 68.15%
# Test Loss: 0.7120, Test Accuracy: 92.06%
# Epoch [293/350], Train Loss: 1.2977, Train Accuracy: 66.49%
# Test Loss: 0.7067, Test Accuracy: 92.31%
# Epoch [294/350], Train Loss: 1.2670, Train Accuracy: 68.42%
# Test Loss: 0.7106, Test Accuracy: 92.28%
# Epoch [295/350], Train Loss: 1.2727, Train Accuracy: 68.02%
# Test Loss: 0.7093, Test Accuracy: 92.20%
# Epoch [296/350], Train Loss: 1.2816, Train Accuracy: 67.65%
# Test Loss: 0.7090, Test Accuracy: 92.36%
# Epoch [297/350], Train Loss: 1.2621, Train Accuracy: 68.58%
# Test Loss: 0.7103, Test Accuracy: 92.14%
# Epoch [298/350], Train Loss: 1.2796, Train Accuracy: 67.89%
# Test Loss: 0.7078, Test Accuracy: 92.41%
# Epoch [299/350], Train Loss: 1.2467, Train Accuracy: 69.40%
# Test Loss: 0.7063, Test Accuracy: 92.50%
# Epoch [300/350], Train Loss: 1.2907, Train Accuracy: 66.99%
# Test Loss: 0.7047, Test Accuracy: 92.36%
# Epoch [301/350], Train Loss: 1.3020, Train Accuracy: 66.40%
# Test Loss: 0.7123, Test Accuracy: 92.45%
# Epoch [302/350], Train Loss: 1.2512, Train Accuracy: 69.19%
# Test Loss: 0.7104, Test Accuracy: 92.27%
# Epoch [303/350], Train Loss: 1.2659, Train Accuracy: 68.48%
# Test Loss: 0.7090, Test Accuracy: 92.37%
# Epoch [304/350], Train Loss: 1.2645, Train Accuracy: 68.26%
# Test Loss: 0.7060, Test Accuracy: 92.21%
# Epoch [305/350], Train Loss: 1.2618, Train Accuracy: 68.95%
# Test Loss: 0.7077, Test Accuracy: 92.39%
# Epoch [306/350], Train Loss: 1.2566, Train Accuracy: 68.50%
# Test Loss: 0.7094, Test Accuracy: 92.33%
# Epoch [307/350], Train Loss: 1.2739, Train Accuracy: 67.81%
# Test Loss: 0.7092, Test Accuracy: 92.30%
# Epoch [308/350], Train Loss: 1.2652, Train Accuracy: 68.46%
# Test Loss: 0.7012, Test Accuracy: 92.51%
# Epoch [309/350], Train Loss: 1.2526, Train Accuracy: 68.77%
# Test Loss: 0.7060, Test Accuracy: 92.33%
# Epoch [310/350], Train Loss: 1.2621, Train Accuracy: 68.30%
# Test Loss: 0.7065, Test Accuracy: 92.28%
# Epoch [311/350], Train Loss: 1.2724, Train Accuracy: 67.94%
# Test Loss: 0.7075, Test Accuracy: 92.34%
# Epoch [312/350], Train Loss: 1.2746, Train Accuracy: 67.83%
# Test Loss: 0.7094, Test Accuracy: 92.35%
# Epoch [313/350], Train Loss: 1.2822, Train Accuracy: 67.36%
# Test Loss: 0.7099, Test Accuracy: 92.05%
# Epoch [314/350], Train Loss: 1.2540, Train Accuracy: 68.74%
# Test Loss: 0.7067, Test Accuracy: 92.27%
# Epoch [315/350], Train Loss: 1.2733, Train Accuracy: 67.67%
# Test Loss: 0.7097, Test Accuracy: 92.20%
# Epoch [316/350], Train Loss: 1.2505, Train Accuracy: 68.81%
# Test Loss: 0.7075, Test Accuracy: 92.27%
# Epoch [317/350], Train Loss: 1.2566, Train Accuracy: 68.52%
# Test Loss: 0.7031, Test Accuracy: 92.41%
# Epoch [318/350], Train Loss: 1.2547, Train Accuracy: 68.93%
# Test Loss: 0.7035, Test Accuracy: 92.35%
# Epoch [319/350], Train Loss: 1.2595, Train Accuracy: 68.58%
# Test Loss: 0.7037, Test Accuracy: 92.23%
# Epoch [320/350], Train Loss: 1.2424, Train Accuracy: 69.49%
# Test Loss: 0.7044, Test Accuracy: 92.22%
# Epoch [321/350], Train Loss: 1.2438, Train Accuracy: 69.47%
# Test Loss: 0.7060, Test Accuracy: 92.25%
# Epoch [322/350], Train Loss: 1.2645, Train Accuracy: 68.23%
# Test Loss: 0.7027, Test Accuracy: 92.41%
# Epoch [323/350], Train Loss: 1.2576, Train Accuracy: 68.42%
# Test Loss: 0.7058, Test Accuracy: 92.36%
# Epoch [324/350], Train Loss: 1.2644, Train Accuracy: 68.59%
# Test Loss: 0.7053, Test Accuracy: 92.40%
# Epoch [325/350], Train Loss: 1.2821, Train Accuracy: 67.18%
# Test Loss: 0.7061, Test Accuracy: 92.29%
# Epoch [326/350], Train Loss: 1.2846, Train Accuracy: 67.28%
# Test Loss: 0.7051, Test Accuracy: 92.38%
# Epoch [327/350], Train Loss: 1.2421, Train Accuracy: 69.47%
# Test Loss: 0.7027, Test Accuracy: 92.44%
# Epoch [328/350], Train Loss: 1.2540, Train Accuracy: 68.95%
# Test Loss: 0.7026, Test Accuracy: 92.37%
# Epoch [329/350], Train Loss: 1.2397, Train Accuracy: 69.50%
# Test Loss: 0.7023, Test Accuracy: 92.42%
# Epoch [330/350], Train Loss: 1.2698, Train Accuracy: 67.86%
# Test Loss: 0.7036, Test Accuracy: 92.38%
# Epoch [331/350], Train Loss: 1.2553, Train Accuracy: 68.49%
# Test Loss: 0.7026, Test Accuracy: 92.52%
# Epoch [332/350], Train Loss: 1.2373, Train Accuracy: 69.84%
# Test Loss: 0.7031, Test Accuracy: 92.46%
# Epoch [333/350], Train Loss: 1.2690, Train Accuracy: 68.14%
# Test Loss: 0.7043, Test Accuracy: 92.32%
# Epoch [334/350], Train Loss: 1.2810, Train Accuracy: 67.44%
# Test Loss: 0.7047, Test Accuracy: 92.33%
# Epoch [335/350], Train Loss: 1.2298, Train Accuracy: 70.19%
# Test Loss: 0.7017, Test Accuracy: 92.42%
# Epoch [336/350], Train Loss: 1.2378, Train Accuracy: 69.53%
# Test Loss: 0.7024, Test Accuracy: 92.29%
# Epoch [337/350], Train Loss: 1.2343, Train Accuracy: 70.07%
# Test Loss: 0.7032, Test Accuracy: 92.38%
# Epoch [338/350], Train Loss: 1.2389, Train Accuracy: 69.54%
# Test Loss: 0.7033, Test Accuracy: 92.21%
# Epoch [339/350], Train Loss: 1.2573, Train Accuracy: 68.55%
# Test Loss: 0.7030, Test Accuracy: 92.24%
# Epoch [340/350], Train Loss: 1.2494, Train Accuracy: 68.90%
# Test Loss: 0.7029, Test Accuracy: 92.25%
# Epoch [341/350], Train Loss: 1.2709, Train Accuracy: 67.85%
# Test Loss: 0.7039, Test Accuracy: 92.18%
# Epoch [342/350], Train Loss: 1.2569, Train Accuracy: 68.64%
# Test Loss: 0.7043, Test Accuracy: 92.21%
# Epoch [343/350], Train Loss: 1.2630, Train Accuracy: 68.37%
# Test Loss: 0.7043, Test Accuracy: 92.27%
# Epoch [344/350], Train Loss: 1.2634, Train Accuracy: 68.28%
# Test Loss: 0.7043, Test Accuracy: 92.28%
# Epoch [345/350], Train Loss: 1.2690, Train Accuracy: 68.27%
# Test Loss: 0.7044, Test Accuracy: 92.30%
# Epoch [346/350], Train Loss: 1.2435, Train Accuracy: 69.21%
# Test Loss: 0.7041, Test Accuracy: 92.34%
# Epoch [347/350], Train Loss: 1.2227, Train Accuracy: 70.41%
# Test Loss: 0.7040, Test Accuracy: 92.31%
# Epoch [348/350], Train Loss: 1.2765, Train Accuracy: 67.43%
# Test Loss: 0.7040, Test Accuracy: 92.32%
# Epoch [349/350], Train Loss: 1.2340, Train Accuracy: 70.05%
# Test Loss: 0.7040, Test Accuracy: 92.33%
# Epoch [350/350], Train Loss: 1.2653, Train Accuracy: 68.22%
# Test Loss: 0.7040, Test Accuracy: 92.33%
# Training finished!

# %%
import matplotlib.pyplot as plt
import torch

# Assuming train_accuracies and test_accuracies are lists of GPU tensors
train_accuracies_cpu = [acc.cpu().item() if isinstance(acc, torch.Tensor) else acc for acc in train_accuracy_record]
test_accuracies_cpu = [acc.cpu().item() if isinstance(acc, torch.Tensor) else acc for acc in test_accuracy_record]

plt.figure(figsize=(10, 6))
plt.plot(range(1, num_epochs + 1), train_accuracies_cpu, label='Train Accuracy')
plt.plot(range(1, num_epochs + 1), test_accuracies_cpu, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Train vs Test Accuracy')
plt.legend()
plt.grid(True)
plt.savefig('accuracy_comparison.png')
plt.show()

# %% [markdown]
# ### Testing
#
# To test the trained model:
#
#
# 1. Ensure `model_checkpoint_epoch_350_local.pt` is in the same directory.
# 2. Run all cells to load the model and perform inference on test data.
# 3. The notebook will display test accuracy and visualize predictions on sample images.
